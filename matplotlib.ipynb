# %% [markdown]
# # SF Salaries Exercise

# %% [markdown]
# # Matplotlib is object-oriented. We recommend directly working with the objects,
# if you need more control and customization of your plots.

# %% [markdown]
# - import pandas as pd

# %%
import pandas as pd

# %% [markdown]
# - Read salariese .CSV as a dataframe called sal.

# %% [markdown]
# - check the head of the datatFrame

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x=np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# functional
plt.plot(x,y)

# %%
plt.plot(x,y,'r-')
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('x Label')
plt.ylabel('y Label')
plt.title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %% [markdown]
# - object-oriented

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('x Label')
axes.set_ylabel('y Label')
axes.set_title('set title')
# Out:
# Text(0.5, 1.0, 'set title')

# %%
#create figuer object
fig =plt.figure()

axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

# %%
#create figuer object
fig =plt.figure()

axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.15,0.4,0.2])

# %%
#create figuer object
fig =plt.figure()

axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.2])

axes1.plot(x,y)
axes1.set_title('LARGER PLOT')
axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %%
fig =plt.figure()

# %%
fig =plt.figure()

axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.3,0.8,0.4,0.3])
axes3=fig.add_axes([0.3,0.2,0.2,0.3])

axes1.plot(x,y)
axes1.set_title('LARGER PLOT')
axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')
axes3.plot()
axes3.set_title('midd plot')
# Out:
# Text(0.5, 1.0, 'midd plot')

# %% [markdown]
# # NO

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
#from colorspacious import cspace_converter
from collections import OrderedDict
cmaps = OrderedDict()

# %%
fig,axes =plt.subplots(nrows=1,ncols=2)
for current_ax in axes:
    current_ax.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-5d027337b966> in <module>
#       1 fig,axes =plt.subplots(nrows=1,ncols=2)
#       2 for current_ax in axes:
# ----> 3     current_ax.plot(x,y)
#
# NameError: name 'x' is not defined

# %%
cmaps['Sequential (2)'] = [
            'binary', 'gist_yarg', 'gist_gray', 'gray', 'bone', 'pink',
            'spring', 'summer', 'autumn', 'winter', 'cool', 'Wistia',
            'hot', 'afmhot', 'gist_heat', 'copper']

# %%
cmaps['Sequential (2)']
# Out:
# ['binary',
#  'gist_yarg',
#  'gist_gray',
#  'gray',
#  'bone',
#  'pink',
#  'spring',
#  'summer',
#  'autumn',
#  'winter',
#  'cool',
#  'Wistia',
#  'hot',
#  'afmhot',
#  'gist_heat',
#  'copper']

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
N = 5
menMeans = (20, 35, 30, 35, -27)
womenMeans = (25, 32, 34, 20, -25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

# %%
fig, ax = plt.subplots()

p1 = ax.bar(ind, menMeans, width, yerr=menStd, label='Men')
p2 = ax.bar(ind, womenMeans, width,
            bottom=menMeans, yerr=womenStd, label='Women')

ax.axhline(0, color='grey', linewidth=0.8)
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(ind)
ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5'))
ax.legend()

# Label with label_type 'center' instead of the default 'edge'
#ax.bar_label(p1, label_type='center')
#ax.bar_label(p2, label_type='center')
#ax.bar_label(p2)

plt.show()

# %%
import numpy as np
store = np.array([0, 9, 0, 1])
cost  = np.array([82, 82, 73, 73])
np_cols = np.column_stack((store, cost))
print(np_cols)
# Out:
# [[ 0 82]
#  [ 9 82]
#  [ 0 73]
#  [ 1 73]]

# %%
import numpy as np
x=np.linspace(0,5,11)
y = x**2

# %%
import pandas as pd

# %% [markdown]
# # YES

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
fig,axes =plt.subplots(nrows=3,ncols=3)
plt.tight_layout()

# %%
fig,axes =plt.subplots(nrows=3,ncols=3)

# %%
#over laping
fig,axes =plt.subplots(nrows=1,ncols=2)
for current_ax in axes:
    current_ax.plot(x,y)

# %%
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
# no over laping
fig,axes = plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[0].set_title('first plot')

axes[1].plot(x,y)
axes[1].set_title('second plot')

plt.tight_layout()

# %% [markdown]
# # Figuer Size and DPI

# %%
fig =plt.figure(figsize=(8,2))
ax= fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes =plt.subplots(figsize=(8,2))
#ax= fig.add_axes([0,0,1,1])
axes.plot(x,y)

# %%
fig,axes =plt.subplots(nrows=2,ncols=1,figsize=(8,2))
axes[0].plot(x,y)
axes[1].plot(x,y)
plt.tight_layout()

# %%
fig

# %%
fig.savefig('my_pic.png',dpi=200)

# %%
fig =plt.figure(figsize=(8,2))
ax= fig.add_axes([0,0,1,1])
ax.plot(x,x)
ax.plot(x,x)

# %%
fig =plt.figure(figsize=(8,2))
ax= fig.add_axes([0,0,1,1])
ax.plot(x,x**2)
ax.plot(x,x**3)

# %%
fig =plt.figure(figsize=(8,2))
ax= fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='x squared')
ax.plot(x,x**3,label='y cubed')
ax.legend()

# %%
fig =plt.figure(figsize=(8,2))
ax= fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='x squared')
ax.plot(x,x**3,label='y cubed')
#ax.legend(loc=10)
ax.legend(loc=(0.1,0.1))
#loc = best=0
# upper right=1
# upper left=2
# lower right=3
# right =5
#center left =6
#center right=7
#lower center=8
#upper center= 9
# center =10

# %% [markdown]
# # plot Appearance

# %%
fig =plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='green',linewidth=10)#rgb hex code

# %%
fig =plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='pink',lw=2,ls='--')

# %%
fig =plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='green',linewidth=0.5,ls='-',marker='o',markersize=20,
        markerfacecolor='yellow',markeredgecolor='pink',markeredgewidth=3)

# %%
fig =plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='pink',lw=2,ls='--')
ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0.0, 2.0)

# %% [markdown]
# # Special polt Types

# %% [markdown]
# - we can create   such as barplots ,historgram,scatter plots and much more
# - most of these types of plots will actully create using seaborn a statisticl plotting library for python

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
#plt.tight_layout(pad=1.08, h_pad=3, w_pad=4)
# Out:
# (array([ 8.,  7.,  4., 14., 18., 12., 10.,  6.,  7., 14.]),
#  array([  8. , 105.6, 203.2, 300.8, 398.4, 496. , 593.6, 691.2, 788.8,
#         886.4, 984. ]),
#  <BarContainer object of 10 artists>)

# %%
data=[np.random.normal(0,std,100) for std in range (1,4)]
#rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);

# %%
fig =plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='pink',lw=2,linestyle='dashdot')

# %% [markdown]
# # Line and marker styles

# %% [markdown]
# - to change the line width we can  use the linewidht or lw keyword argument .
# - the line style can be select using the linestyle or ls keyword argument

# %%
figure
t = 0:pi/20:2*pi;
plot(t,sin(t),'-.r*')
hold on
plot(t,sin(t-pi/2),'--mo')
plot(t,sin(t-pi),':bs')
hold off
# Out:
#   File "<ipython-input-128-aad158e972b8>", line 2
#     t = 0:pi/20:2*pi;
#          ^
# SyntaxError: invalid syntax

# %%
t = 0:pi/20:2*pi;
figure
plot(t,sin(2*t),'-mo',...
    'LineWidth',2,...
    'MarkerEdgeColor','k',...
    'MarkerFaceColor',[.49 1 .63],...
    'MarkerSize',10)
# Out:
#   File "<ipython-input-127-6109b8d52285>", line 1
#     t = 0:pi/20:2*pi;
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Control over axis appearance
# - In this section we will look at controlling axis sizing properties ina matplotlib figure.

# %% [markdown]
# # plot range

# %% [markdown]
# the arnge of the axes using set_ylim and set_xlim method inthe axis object or axis ('tight')for
# atuomatically getting "tightly  fitted" axes ranges.
