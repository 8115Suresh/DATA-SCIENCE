# %% [markdown]
# # Data

# %%
import numpy as np
x=np.arange(0,100)
y=x*2
z=x**2

# %% [markdown]
# Import matplotlib pyplot as plt and set % matplotlib inline if you are using the jupyter notebook.
# what command do you use if you aren't using the jupyter notebook?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.show()

# %% [markdown]
# - create a figure object called fig using olt.figuer()
# - use add_axes to add an axes to the figure canvas at [0,0,1,1] call this new axis ax.
# - plot(x,y) on that axes and set the labels and titles to match plot below

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# - create a figure aobect and put two axes on it ax1 and ax2 located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.

# %%
fig = plt.figure()
axes1=fig.add_axes([0,0,1,1])
axes2=fig.add_axes([0.2,0.5,.2,.2])

# %% [markdown]
# - Now plot(x,y) on both axes and call your figure object to show it

# %%
fig = plt.figure()
axes1=fig.add_axes([0,0,1,1])
axes2=fig.add_axes([0.2,0.5,.2,.2])
axes1.plot(x,y)
axes2.plot(x,y)

# %% [markdown]
# - Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]

# %%
fig = plt.figure()
axes1=fig.add_axes([0,0,1,1])
axes2=fig.add_axes([0.2,0.5,.4,.4])

# %% [markdown]
# - now use x,y and z arrays to recretate the plot below notice the x limits and y limits on the inserted plot

# %%
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,.2,.2])
#large
ax.plot(x,z)
ax.set_xlabel('x')
ax.set_ylabel('y')
#insert
ax2.plot(x,y)
ax2.set_title('zoom')
ax2.set_xlabel('x')
ax2.set_xlabel('y')
ax2.set_xlim([20,22])
ax2.set_ylim([30,50])
# Out:
# (30.0, 50.0)

# %% [markdown]
# - use plt.subplots(nrows=1,ncols=2) to create the below

# %%
fig,axes = plt.subplots(1,2)
#fig = plt.figure()
#axes=plt.subplots(nrows=1,ncols=2)lsl

# %% [markdown]
# - now plot (x,y) and (x,z) on the axes ply arond with the linewidth and style

# %%
fig,axes = plt.subplots(1,2)

axes[0].plot(x,y,color='blue',lw=3,ls='--')
axes[1].plot(x,z,color='red',lw=3)

# %% [markdown]
# - see iy you can resie the plot by adding the figsize () argument in plt.subplots ( ) are  copying and pasting previous code

# %%
 fig,axes = plt.subplots(1,2,figsize=(12,2))

axes[0].plot(x,y,color='blue',lw=3,ls='--')
axes[1].plot(x,z,color='red',lw=3)
